# %% [markdown]
# # Countries of interest
#
# This worksheet is part of a project to analyse and visualise data on the COVID-19 outbreak and will be run once a day.<br>
# It shows data from a selection of countries deemed interesting through personal relations, as well as for interesting reference.

# %%
import my_tools as mt

countries = ['China', 'France', 'Italy', 'United States of America', 'Spain', 'United Kingdom', 'Belgium', 'Iran', 'Ukraine', 'South Korea']
countries.sort()
# Out:
# Latest update at 2020-04-13
# Latest data point at 2020-04-12

# %% [markdown]
# ### Table
#
# This table holds the latest information on each of the countries.
#
# - Incidence = New cases / Population
# - Prevalence = Total Cases / Popuulation
# - Mortality = Total Deaths / Total cases

# %%
mt.show_table(countries)
# Out:
# <style  type="text/css" >
# </style><table id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774f" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total</th>        <th class="col_heading level0 col1" >Prevalence</th>        <th class="col_heading level0 col2" >Mortality</th>        <th class="col_heading level0 col3" >Today</th>        <th class="col_heading level0 col4" >3 days av</th>        <th class="col_heading level0 col5" >Weekly av</th>        <th class="col_heading level0 col6" >Incidence today</th>        <th class="col_heading level0 col7" >Incidence 3 days av</th>        <th class="col_heading level0 col8" >Incidence weekly av</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774flevel0_row0" class="row_heading level0 row0" rowspan=2>Global</th>
#                         <th id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774flevel1_row0" class="row_heading level1 row0" >Cases</th>
#                         <td id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774frow0_col0" class="data row0 col0" >1734913</td>
#                         <td id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774frow0_col1" class="data row0 col1" >0.023%</td>
#                         <td id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774frow0_col2" class="data row0 col2" ></td>
#                         <td id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774frow0_col3" class="data row0 col3" >81707</td>
#                         <td id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774frow0_col4" class="data row0 col4" >86031</td>
#                         <td id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774frow0_col5" class="data row0 col5" >80078</td>
#                         <td id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774frow0_col6" class="data row0 col6" >0.001%</td>
#                         <td id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774frow0_col7" class="data row0 col7" >0.001%</td>
#                         <td id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774frow0_col8" class="data row0 col8" >0.001%</td>
#             </tr>
#             <tr>
#                                 <th id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774flevel1_row1" class="row_heading level1 row1" >Deaths</th>
#                         <td id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774frow1_col0" class="data row1 col0" >108192</td>
#                         <td id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774frow1_col1" class="data row1 col1" ></td>
#                         <td id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774frow1_col2" class="data row1 col2" >6.236%</td>
#                         <td id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774frow1_col3" class="data row1 col3" >6104</td>
#                         <td id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774frow1_col4" class="data row1 col4" >6792</td>
#                         <td id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774frow1_col5" class="data row1 col5" >6274</td>
#                         <td id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774frow1_col6" class="data row1 col6" ></td>
#                         <td id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774frow1_col7" class="data row1 col7" ></td>
#                         <td id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774frow1_col8" class="data row1 col8" ></td>
#             </tr>
#             <tr>
#                         <th id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774flevel0_row2" class="row_heading level0 row2" rowspan=2>Belgium</th>
#                         <th id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774flevel1_row2" class="row_heading level1 row2" >Cases</th>
#                         <td id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774frow2_col0" class="data row2 col0" >28018</td>
#                         <td id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774frow2_col1" class="data row2 col1" >0.245%</td>
#                         <td id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774frow2_col2" class="data row2 col2" ></td>
#                         <td id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774frow2_col3" class="data row2 col3" >1351</td>
#                         <td id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774frow2_col4" class="data row2 col4" >1538</td>
#                         <td id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774frow2_col5" class="data row2 col5" >1369</td>
#                         <td id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774frow2_col6" class="data row2 col6" >0.012%</td>
#                         <td id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774frow2_col7" class="data row2 col7" >0.013%</td>
#                         <td id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774frow2_col8" class="data row2 col8" >0.012%</td>
#             </tr>
#             <tr>
#                                 <th id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774flevel1_row3" class="row_heading level1 row3" >Deaths</th>
#                         <td id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774frow3_col0" class="data row3 col0" >3346</td>
#                         <td id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774frow3_col1" class="data row3 col1" ></td>
#                         <td id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774frow3_col2" class="data row3 col2" >11.942%</td>
#                         <td id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774frow3_col3" class="data row3 col3" >327</td>
#                         <td id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774frow3_col4" class="data row3 col4" >368</td>
#                         <td id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774frow3_col5" class="data row3 col5" >294</td>
#                         <td id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774frow3_col6" class="data row3 col6" ></td>
#                         <td id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774frow3_col7" class="data row3 col7" ></td>
#                         <td id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774frow3_col8" class="data row3 col8" ></td>
#             </tr>
#             <tr>
#                         <th id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774flevel0_row4" class="row_heading level0 row4" rowspan=2>China</th>
#                         <th id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774flevel1_row4" class="row_heading level1 row4" >Cases</th>
#                         <td id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774frow4_col0" class="data row4 col0" >83097</td>
#                         <td id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774frow4_col1" class="data row4 col1" >0.006%</td>
#                         <td id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774frow4_col2" class="data row4 col2" ></td>
#                         <td id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774frow4_col3" class="data row4 col3" >93</td>
#                         <td id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774frow4_col4" class="data row4 col4" >75</td>
#                         <td id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774frow4_col5" class="data row4 col5" >74</td>
#                         <td id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774frow4_col6" class="data row4 col6" >0.000%</td>
#                         <td id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774frow4_col7" class="data row4 col7" >0.000%</td>
#                         <td id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774frow4_col8" class="data row4 col8" >0.000%</td>
#             </tr>
#             <tr>
#                                 <th id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774flevel1_row5" class="row_heading level1 row5" >Deaths</th>
#                         <td id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774frow5_col0" class="data row5 col0" >3343</td>
#                         <td id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774frow5_col1" class="data row5 col1" ></td>
#                         <td id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774frow5_col2" class="data row5 col2" >4.023%</td>
#                         <td id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774frow5_col3" class="data row5 col3" >0</td>
#                         <td id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774frow5_col4" class="data row5 col4" >1</td>
#                         <td id="T_bc7b13ba_7d72_11ea_8cfb_0fed7701774frow5_col5" class="data row5 col5" >1</td>

# %% [markdown]
# ### Amount of cases, deaths
#
# These plots show the amount of cases and deaths over time.
#
# Do note that these numbers are reported by the countries, meaning they are accurate for as much as each country is testing their population. Though the confirmed cases will always be one or two weeks behind the actual numbers. As for the confirmed deaths, again countries can differ. Where, for example Belgium counts every death in the country due to COVID-19, Poland on the other hand only counts confirmed cases that died in the hospitals. <br>
# Always keep these things in mind when looking at any COVID-19 data.

# %%
mt.plot_spread('cases', '3days', countries)
mt.plot_spread('cases', 'total', countries, leg='r')

# %% [markdown]
# Since all of these trends are expronential, it is interesting to look at the on a logarithmic scale.This is mainly used to compare their exponential trends, represented by the angle of the line towards the x-axis. For this reason we will translate them over the x-axis in a way that each country starts from the point they had their first 100 cases, or 10 deaths. This makes them line up neatly to compare their angles.

# %%
mt.plot_spread('cases', '3days', countries, scale='log')
mt.plot_spread('cases', 'total', countries, scale='log', leg='r')

# %% [markdown]
# ### Incidence and Prevalence
#
# Since incidence and prevalence are relative to the population size, we can add the global information as a reference, mainly in the plot that are on the logarithmic scale, without messing up the scale of our plots.

# %%
countries.append('Global')

mt.plot_spread('incidence', '3days', countries)
mt.plot_spread('incidence', '3days', countries, scale='log', leg='r')

# %% [markdown]
# ### Mortality

# %%
mt.plot_mortality(countries)

# %% [markdown]
# ### Trends
#
# Show the growth rate compared to the total amount of cases, both relative to the population size.<br>
# Considering time is respresented by how the countries move on the graph, an animated version of this graph, showing the progression over time, will also be saved in Dynamic-Trends/.

# %%
mt.plot_trends_dynamically('countries_of_interest', countries)
# Out:
# No handles with labels found to put in legend.
